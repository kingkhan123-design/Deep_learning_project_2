# %%
import tensorflow as tf
# Out:
# WARNING:tensorflow:From c:\Users\Vyankatesh Pandit\Machine Learning\Deep learning\ANN_Classifier\venv2\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from tensorflow.keras.preprocessing.text import one_hot
sent=['the glass of milk',
      'the glass of juice',
      'the cup of tea',
      'I am a good boy',
      'I am good developer',
      'understand the meaning of word',
      'your videos are good']

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am good developer',
#  'understand the meaning of word',
#  'your videos are good']

# %%
## Define the vocabulary size
voc_size=1000

# %%
## One hot representation for every word
one_hot_representation=[one_hot(word,voc_size) for word in sent]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am good developer',
#  'understand the meaning of word',
#  'your videos are good']

# %%
one_hot_representation
# Out:
# [[944, 772, 322, 586],
#  [944, 772, 322, 485],
#  [944, 860, 322, 136],
#  [451, 295, 919, 117, 413],
#  [451, 295, 117, 560],
#  [230, 944, 757, 322, 618],
#  [131, 964, 519, 117]]

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import pad_sequences

# %%
import numpy as np

# %%
sent_length=8
embedded_docs=pad_sequences(one_hot_representation,padding='pre',maxlen=sent_length)

# %%
print(embedded_docs)
# Out:
# [[  0   0   0   0 944 772 322 586]
#  [  0   0   0   0 944 772 322 485]
#  [  0   0   0   0 944 860 322 136]
#  [  0   0   0 451 295 919 117 413]
#  [  0   0   0   0 451 295 117 560]
#  [  0   0   0 230 944 757 322 618]
#  [  0   0   0   0 131 964 519 117]]

# %%
## Feature Representation
dim=10
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')
# Out:
# WARNING:tensorflow:From c:\Users\Vyankatesh Pandit\Machine Learning\Deep learning\ANN_Classifier\venv2\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\Vyankatesh Pandit\Machine Learning\Deep learning\ANN_Classifier\venv2\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             10000
#
# =================================================================
# Total params: 10000 (39.06 KB)
# Trainable params: 10000 (39.06 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embedded_docs)
# Out:
# 1/1 [==============================] - 0s 271ms/step
# array([[[ 0.03896211, -0.01305318,  0.04814802, -0.03750124,
#          -0.02248055,  0.01959392,  0.02161754,  0.02376494,
#          -0.04473985, -0.0016454 ],
#         [ 0.03896211, -0.01305318,  0.04814802, -0.03750124,
#          -0.02248055,  0.01959392,  0.02161754,  0.02376494,
#          -0.04473985, -0.0016454 ],
#         [ 0.03896211, -0.01305318,  0.04814802, -0.03750124,
#          -0.02248055,  0.01959392,  0.02161754,  0.02376494,
#          -0.04473985, -0.0016454 ],
#         [ 0.03896211, -0.01305318,  0.04814802, -0.03750124,
#          -0.02248055,  0.01959392,  0.02161754,  0.02376494,
#          -0.04473985, -0.0016454 ],
#         [-0.03855409, -0.02474848, -0.01819795,  0.04860293,
#           0.02316697,  0.00666568, -0.02998722, -0.03341736,
#           0.00670648, -0.03832486],
#         [ 0.03590571,  0.04899717,  0.00730272, -0.0424209 ,
#          -0.02582029,  0.03237058, -0.00806063,  0.04858228,
#          -0.03539247,  0.03353054],
#         [-0.00245308,  0.0014824 ,  0.00122243,  0.0271562 ,
#          -0.02000665, -0.00463582,  0.03262218, -0.02544518,
#          -0.02254038,  0.04787287],
#         [ 0.0230864 ,  0.0339402 ,  0.02929946,  0.01370715,
#          -0.00713104,  0.01665073,  0.03030166,  0.00749289,
#           0.04526855,  0.04742484]],
#
#        [[ 0.03896211, -0.01305318,  0.04814802, -0.03750124,
#          -0.02248055,  0.01959392,  0.02161754,  0.02376494,
#          -0.04473985, -0.0016454 ],
#         [ 0.03896211, -0.01305318,  0.04814802, -0.03750124,
#          -0.02248055,  0.01959392,  0.02161754,  0.02376494,
#          -0.04473985, -0.0016454 ],
#         [ 0.03896211, -0.01305318,  0.04814802, -0.03750124,
#          -0.02248055,  0.01959392,  0.02161754,  0.02376494,
#          -0.04473985, -0.0016454 ],
#         [ 0.03896211, -0.01305318,  0.04814802, -0.03750124,
#          -0.02248055,  0.01959392,  0.02161754,  0.02376494,
#          -0.04473985, -0.0016454 ],
#         [-0.03855409, -0.02474848, -0.01819795,  0.04860293,
#           0.02316697,  0.00666568, -0.02998722, -0.03341736,
#           0.00670648, -0.03832486],
#         [ 0.03590571,  0.04899717,  0.00730272, -0.0424209 ,
#          -0.02582029,  0.03237058, -0.00806063,  0.04858228,
#          -0.03539247,  0.03353054],
#         [-0.00245308,  0.0014824 ,  0.00122243,  0.0271562 ,
#          -0.02000665, -0.00463582,  0.03262218, -0.02544518,
#          -0.02254038,  0.04787287],
#         [-0.0156317 , -0.0104524 , -0.02819065, -0.04768562,
#           0.01952476,  0.01220632, -0.00713684,  0.03886881,
#          -0.04344568,  0.04069737]],
#
#        [[ 0.03896211, -0.01305318,  0.04814802, -0.03750124,
#          -0.02248055,  0.01959392,  0.02161754,  0.02376494,
#          -0.04473985, -0.0016454 ],
#         [ 0.03896211, -0.01305318,  0.04814802, -0.03750124,
#          -0.02248055,  0.01959392,  0.02161754,  0.02376494,
#          -0.04473985, -0.0016454 ],
#         [ 0.03896211, -0.01305318,  0.04814802, -0.03750124,
#          -0.02248055,  0.01959392,  0.02161754,  0.02376494,
#          -0.04473985, -0.0016454 ],
#         [ 0.03896211, -0.01305318,  0.04814802, -0.03750124,
#          -0.02248055,  0.01959392,  0.02161754,  0.02376494,
#          -0.04473985, -0.0016454 ],
#         [-0.03855409, -0.02474848, -0.01819795,  0.04860293,
#           0.02316697,  0.00666568, -0.02998722, -0.03341736,
#           0.00670648, -0.03832486],
#         [ 0.0456033 , -0.0033353 , -0.03749638, -0.04675862,
#          -0.04518026, -0.03432266,  0.04482634, -0.04916376,
#          -0.04191007,  0.00126805],
#         [-0.00245308,  0.0014824 ,  0.00122243,  0.0271562 ,
#          -0.02000665, -0.00463582,  0.03262218, -0.02544518,
#          -0.02254038,  0.04787287],
#         [ 0.02133979, -0.02297446, -0.02135608, -0.007245  ,
#          -0.03274154, -0.0221172 , -0.00920733,  0.01886947,
#           0.00485335,  0.0219126 ]],
#
#        [[ 0.03896211, -0.01305318,  0.04814802, -0.03750124,
#          -0.02248055,  0.01959392,  0.02161754,  0.02376494,
#          -0.04473985, -0.0016454 ],
#         [ 0.03896211, -0.01305318,  0.04814802, -0.03750124,
#          -0.02248055,  0.01959392,  0.02161754,  0.02376494,
#          -0.04473985, -0.0016454 ],
#         [ 0.03896211, -0.01305318,  0.04814802, -0.03750124,
#          -0.02248055,  0.01959392,  0.02161754,  0.02376494,
#          -0.04473985, -0.0016454 ],
#         [ 0.04244537,  0.01046468, -0.04991932,  0.02916196,
#           0.04811497,  0.03347601, -0.00893265, -0.01200579,
#          -0.0484331 ,  0.04457977],
#         [ 0.03611717, -0.04739497, -0.00735794, -0.0499218 ,
#          -0.01242267,  0.03928233,  0.01846686,  0.00582527,
#           0.00814686,  0.02296933],
#         [ 0.0242165 ,  0.01609434,  0.01927603, -0.01782721,
#           0.04048021, -0.01453427,  0.03172928, -0.02868472,
#           0.00228814, -0.04686416],
#         [ 0.03054321, -0.04501998,  0.02455324, -0.03331875,
#          -0.00491021,  0.04251966,  0.01272834, -0.01403559,
#          -0.01374446, -0.002952  ],
#         [ 0.01160628, -0.01227468,  0.01452455, -0.03074266,
#          -0.04806836, -0.03545193,  0.01444032,  0.02468176,
#          -0.01384096, -0.04255746]],
#
#        [[ 0.03896211, -0.01305318,  0.04814802, -0.03750124,
#          -0.02248055,  0.01959392,  0.02161754,  0.02376494,
#          -0.04473985, -0.0016454 ],
#         [ 0.03896211, -0.01305318,  0.04814802, -0.03750124,
#          -0.02248055,  0.01959392,  0.02161754,  0.02376494,
#          -0.04473985, -0.0016454 ],
#         [ 0.03896211, -0.01305318,  0.04814802, -0.03750124,
#          -0.02248055,  0.01959392,  0.02161754,  0.02376494,
#          -0.04473985, -0.0016454 ],
#         [ 0.03896211, -0.01305318,  0.04814802, -0.03750124,
#          -0.02248055,  0.01959392,  0.02161754,  0.02376494,
#          -0.04473985, -0.0016454 ],
#         [ 0.04244537,  0.01046468, -0.04991932,  0.02916196,
#           0.04811497,  0.03347601, -0.00893265, -0.01200579,
#          -0.0484331 ,  0.04457977],
#         [ 0.03611717, -0.04739497, -0.00735794, -0.0499218 ,
#          -0.01242267,  0.03928233,  0.01846686,  0.00582527,
#           0.00814686,  0.02296933],
#         [ 0.03054321, -0.04501998,  0.02455324, -0.03331875,
#          -0.00491021,  0.04251966,  0.01272834, -0.01403559,
#          -0.01374446, -0.002952  ],
#         [ 0.02154421,  0.01405102, -0.04817486,  0.00380808,
#           0.03182659, -0.0441637 ,  0.04956262,  0.04652388,
#          -0.04915141, -0.04817258]],
#
#        [[ 0.03896211, -0.01305318,  0.04814802, -0.03750124,
#          -0.02248055,  0.01959392,  0.02161754,  0.02376494,
#          -0.04473985, -0.0016454 ],
#         [ 0.03896211, -0.01305318,  0.04814802, -0.03750124,
#          -0.02248055,  0.01959392,  0.02161754,  0.02376494,
#          -0.04473985, -0.0016454 ],
#         [ 0.03896211, -0.01305318,  0.04814802, -0.03750124,
#          -0.02248055,  0.01959392,  0.02161754,  0.02376494,
#          -0.04473985, -0.0016454 ],
#         [ 0.01502201,  0.00781822,  0.00919835,  0.04279237,
#          -0.0100798 ,  0.03511686, -0.00184399, -0.00713656,
#          -0.00068264, -0.03499087],
#         [-0.03855409, -0.02474848, -0.01819795,  0.04860293,
#           0.02316697,  0.00666568, -0.02998722, -0.03341736,
#           0.00670648, -0.03832486],
#         [ 0.02516231,  0.01233784,  0.02991922,  0.01515703,
#           0.00842994, -0.02593253,  0.03658341,  0.01639948,
#           0.03705226,  0.04256146],
#         [-0.00245308,  0.0014824 ,  0.00122243,  0.0271562 ,
#          -0.02000665, -0.00463582,  0.03262218, -0.02544518,
#          -0.02254038,  0.04787287],
#         [ 0.00552293, -0.01361423, -0.04524824, -0.00824082,
#          -0.01030891, -0.04422598, -0.02321116, -0.00412999,
#           0.01210617,  0.02111801]],
#
#        [[ 0.03896211, -0.01305318,  0.04814802, -0.03750124,
#          -0.02248055,  0.01959392,  0.02161754,  0.02376494,
#          -0.04473985, -0.0016454 ],
#         [ 0.03896211, -0.01305318,  0.04814802, -0.03750124,
#          -0.02248055,  0.01959392,  0.02161754,  0.02376494,
#          -0.04473985, -0.0016454 ],
#         [ 0.03896211, -0.01305318,  0.04814802, -0.03750124,
#          -0.02248055,  0.01959392,  0.02161754,  0.02376494,
#          -0.04473985, -0.0016454 ],
#         [ 0.03896211, -0.01305318,  0.04814802, -0.03750124,
#          -0.02248055,  0.01959392,  0.02161754,  0.02376494,
#          -0.04473985, -0.0016454 ],
#         [ 0.04032738,  0.01732249, -0.04621571,  0.02402487,
#           0.00508084,  0.03814346, -0.02973193,  0.02082646,
#          -0.01929994, -0.03643087],
#         [ 0.02427823, -0.00559528, -0.00147545,  0.04214991,
#          -0.0248355 , -0.03229088,  0.0024068 ,  0.01866808,
#           0.03691168, -0.01415204],
#         [-0.01096783, -0.0173998 , -0.0079635 , -0.01529098,
#          -0.01190932, -0.00986337, -0.03191335, -0.00425183,
#          -0.00811798,  0.04018338],
#         [ 0.03054321, -0.04501998,  0.02455324, -0.03331875,
#          -0.00491021,  0.04251966,  0.01272834, -0.01403559,
#          -0.01374446, -0.002952  ]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([  0,   0,   0,   0, 944, 772, 322, 586])

# %%
model.predict(embedded_docs[0])
# Out:
# 1/1 [==============================] - 0s 75ms/step
# array([[ 0.03896211, -0.01305318,  0.04814802, -0.03750124, -0.02248055,
#          0.01959392,  0.02161754,  0.02376494, -0.04473985, -0.0016454 ],
#        [ 0.03896211, -0.01305318,  0.04814802, -0.03750124, -0.02248055,
#          0.01959392,  0.02161754,  0.02376494, -0.04473985, -0.0016454 ],
#        [ 0.03896211, -0.01305318,  0.04814802, -0.03750124, -0.02248055,
#          0.01959392,  0.02161754,  0.02376494, -0.04473985, -0.0016454 ],
#        [ 0.03896211, -0.01305318,  0.04814802, -0.03750124, -0.02248055,
#          0.01959392,  0.02161754,  0.02376494, -0.04473985, -0.0016454 ],
#        [-0.03855409, -0.02474848, -0.01819795,  0.04860293,  0.02316697,
#          0.00666568, -0.02998722, -0.03341736,  0.00670648, -0.03832486],
#        [ 0.03590571,  0.04899717,  0.00730272, -0.0424209 , -0.02582029,
#          0.03237058, -0.00806063,  0.04858228, -0.03539247,  0.03353054],
#        [-0.00245308,  0.0014824 ,  0.00122243,  0.0271562 , -0.02000665,
#         -0.00463582,  0.03262218, -0.02544518, -0.02254038,  0.04787287],
#        [ 0.0230864 ,  0.0339402 ,  0.02929946,  0.01370715, -0.00713104,
#          0.01665073,  0.03030166,  0.00749289,  0.04526855,  0.04742484]],
#       dtype=float32)
